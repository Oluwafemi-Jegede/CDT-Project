# %% [markdown]
# ### Pycaret
#
#
# `PyCaret` is an open-source, **low-code machine learning library in Python** that aims to **reduce the cycle time from hypothesis to insights**. It is well suited for seasoned data scientists who want to **increase the productivity** of their ML experiments by using PyCaret in their workflows or for citizen data scientists and those new to data science with little or no background in coding.
#
# We will run setup a pycaret model for this problem using just the training dataset, this is help select the best set of models to use intead of trying different types of models looking for the best. pycaret will help us run 14 types of models and compare them for the best.
#
# For this problem we will need to we will have to create a dataFrame for the problem, because input to `pycaret` has to be a dataframe
#
#
# Due to dependencies on this environment and PC, the pycaret was run on Google Colab
#
# This Notebook was ran on [Google Colab](https://colab.research.google.com/drive/1wAUrjvdhQ3wIoJsg5ZmEBEdb87s1pQDq#scrollTo=a_Av-SBY9DcD)

# %%
import pandas as pd
import numpy as np
from pycaret.classification import compare_models
from pycaret.classification import setup
from pycaret.classification import tune_model
from sklearn.ensemble import RandomForestClassifier

# %%
#data in project folder
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/train.csv',index_col=0)
df.head(3)
# Out:
#    product_weight_g  carrier_Week     price  carrier_DofW  freight_value  \
# 0          0.499971      0.627451  0.377553      0.666667       0.308727
# 1          0.610764      0.431373  0.399339      0.666667       0.389783
# 2          0.435092      0.156863  0.307300      0.666667       0.451220
#
#    order_item_id  product_volume_cm3  distance_category  same_state  \
# 0           0.05            0.246950           0.000000         1.0
# 1           0.00            0.295461           0.000000         1.0
# 2           0.00            0.239556           0.333333         0.0
#
#    customer_state_encode  seller_state_encode  Holiday  delivery_window
# 0               1.000000                  0.0      0.0                0
# 1               0.000000                  0.0      0.0                0
# 2               0.666667                  1.0      1.0                1

# %%
# setup the dataset
grid =setup(data=df, target='delivery_window', html=False, silent=True, verbose=False)

# evaluate models and compare models
best = compare_models()
# Out:
#                   Model  Accuracy     AUC  Recall   Prec.      F1   Kappa  \
# lr  Logistic Regression    0.6452  0.7875  0.6054  0.6231  0.6174  0.4066
#
#        MCC  TT (Sec)
# lr  0.4201     2.643
#                       Model  Accuracy     AUC  Recall   Prec.      F1   Kappa  \
# knn  K Neighbors Classifier    0.6562  0.7894  0.6396  0.6511  0.6523  0.4462
# lr      Logistic Regression    0.6452  0.7875  0.6054  0.6231  0.6174  0.4066
#
#         MCC  TT (Sec)
# knn  0.4470     2.126
# lr   0.4201     2.643
#                       Model  Accuracy     AUC  Recall   Prec.      F1   Kappa  \
# knn  K Neighbors Classifier    0.6562  0.7894  0.6396  0.6511  0.6523  0.4462
# lr      Logistic Regression    0.6452  0.7875  0.6054  0.6231  0.6174  0.4066
# nb              Naive Bayes    0.6152  0.7701  0.5833  0.5876  0.5630  0.3682
#
#         MCC  TT (Sec)
# knn  0.4470     2.126
# lr   0.4201     2.643
# nb   0.3922     0.066
#                         Model  Accuracy     AUC  Recall   Prec.      F1  \
# knn    K Neighbors Classifier    0.6562  0.7894  0.6396  0.6511  0.6523
# lr        Logistic Regression    0.6452  0.7875  0.6054  0.6231  0.6174
# dt   Decision Tree Classifier    0.6240  0.6993  0.6059  0.6264  0.6251
# nb                Naive Bayes    0.6152  0.7701  0.5833  0.5876  0.5630
#
#       Kappa     MCC  TT (Sec)
# knn  0.4462  0.4470     2.126
# lr   0.4066  0.4201     2.643
# dt   0.3952  0.3953     0.399
# nb   0.3682  0.3922     0.066
#                         Model  Accuracy     AUC  Recall   Prec.      F1  \
# knn    K Neighbors Classifier    0.6562  0.7894  0.6396  0.6511  0.6523
# lr        Logistic Regression    0.6452  0.7875  0.6054  0.6231  0.6174
# svm       SVM - Linear Kernel    0.6313  0.0000  0.5981  0.6254  0.5603
# dt   Decision Tree Classifier    0.6240  0.6993  0.6059  0.6264  0.6251
# nb                Naive Bayes    0.6152  0.7701  0.5833  0.5876  0.5630
#
#       Kappa     MCC  TT (Sec)
# knn  0.4462  0.4470     2.126
# lr   0.4066  0.4201     2.643
# svm  0.3853  0.4227     0.415
# dt   0.3952  0.3953     0.399
# nb   0.3682  0.3922     0.066
#                           Model  Accuracy     AUC  Recall   Prec.      F1  \
# knn      K Neighbors Classifier    0.6562  0.7894  0.6396  0.6511  0.6523
# lr          Logistic Regression    0.6452  0.7875  0.6054  0.6231  0.6174
# ridge          Ridge Classifier    0.6338  0.0000  0.5976  0.6153  0.5811
# svm         SVM - Linear Kernel    0.6313  0.0000  0.5981  0.6254  0.5603
# dt     Decision Tree Classifier    0.6240  0.6993  0.6059  0.6264  0.6251
# nb                  Naive Bayes    0.6152  0.7701  0.5833  0.5876  0.5630
#
#         Kappa     MCC  TT (Sec)
# knn    0.4462  0.4470     2.126
# lr     0.4066  0.4201     2.643
# ridge  0.3893  0.4165     0.066
# svm    0.3853  0.4227     0.415
# dt     0.3952  0.3953     0.399
# nb     0.3682  0.3922     0.066
#                           Model  Accuracy     AUC  Recall   Prec.      F1  \
# rf     Random Forest Classifier    0.7064  0.8468  0.6799  0.6979  0.6996
# knn      K Neighbors Classifier    0.6562  0.7894  0.6396  0.6511  0.6523
# lr          Logistic Regression    0.6452  0.7875  0.6054  0.6231  0.6174
# ridge          Ridge Classifier    0.6338  0.0000  0.5976  0.6153  0.5811
# svm         SVM - Linear Kernel    0.6313  0.0000  0.5981  0.6254  0.5603
# dt     Decision Tree Classifier    0.6240  0.6993  0.6059  0.6264  0.6251
# nb                  Naive Bayes    0.6152  0.7701  0.5833  0.5876  0.5630
#
#         Kappa     MCC  TT (Sec)
# rf     0.5178  0.5203     8.366
# knn    0.4462  0.4470     2.126
# lr     0.4066  0.4201     2.643
# ridge  0.3893  0.4165     0.066
# svm    0.3853  0.4227     0.415
# dt     0.3952  0.3953     0.399
# nb     0.3682  0.3922     0.066
#                                  Model  Accuracy     AUC  Recall   Prec.  \
# rf            Random Forest Classifier    0.7064  0.8468  0.6799  0.6979
# knn             K Neighbors Classifier    0.6562  0.7894  0.6396  0.6511
# lr                 Logistic Regression    0.6452  0.7875  0.6054  0.6231
# qda    Quadratic Discriminant Analysis    0.6357  0.7881  0.6045  0.6131
# ridge                 Ridge Classifier    0.6338  0.0000  0.5976  0.6153
# svm                SVM - Linear Kernel    0.6313  0.0000  0.5981  0.6254
# dt            Decision Tree Classifier    0.6240  0.6993  0.6059  0.6264
# nb                         Naive Bayes    0.6152  0.7701  0.5833  0.5876
#
#            F1   Kappa     MCC  TT (Sec)
# rf     0.6996  0.5178  0.5203     8.366
# knn    0.6523  0.4462  0.4470     2.126
# lr     0.6174  0.4066  0.4201     2.643
# qda    0.6002  0.3988  0.4151     0.081
# ridge  0.5811  0.3893  0.4165     0.066
# svm    0.5603  0.3853  0.4227     0.415
# dt     0.6251  0.3952  0.3953     0.399
# nb     0.5630  0.3682  0.3922     0.066
#                                  Model  Accuracy     AUC  Recall   Prec.  \
# rf            Random Forest Classifier    0.7064  0.8468  0.6799  0.6979
# ada               Ada Boost Classifier    0.6695  0.7935  0.6356  0.6562
# knn             K Neighbors Classifier    0.6562  0.7894  0.6396  0.6511
# lr                 Logistic Regression    0.6452  0.7875  0.6054  0.6231
# qda    Quadratic Discriminant Analysis    0.6357  0.7881  0.6045  0.6131
# ridge                 Ridge Classifier    0.6338  0.0000  0.5976  0.6153
# svm                SVM - Linear Kernel    0.6313  0.0000  0.5981  0.6254
# dt            Decision Tree Classifier    0.6240  0.6993  0.6059  0.6264
# nb                         Naive Bayes    0.6152  0.7701  0.5833  0.5876
#
#            F1   Kappa     MCC  TT (Sec)
# rf     0.6996  0.5178  0.5203     8.366
# ada    0.6583  0.4537  0.4580     1.932
# knn    0.6523  0.4462  0.4470     2.126
# lr     0.6174  0.4066  0.4201     2.643
# qda    0.6002  0.3988  0.4151     0.081
# ridge  0.5811  0.3893  0.4165     0.066
# svm    0.5603  0.3853  0.4227     0.415
# dt     0.6251  0.3952  0.3953     0.399
# nb     0.5630  0.3682  0.3922     0.066
#                                  Model  Accuracy     AUC  Recall   Prec.  \
# rf            Random Forest Classifier    0.7064  0.8468  0.6799  0.6979
# gbc       Gradient Boosting Classifier    0.6863  0.8332  0.6536  0.6738
# ada               Ada Boost Classifier    0.6695  0.7935  0.6356  0.6562
# knn             K Neighbors Classifier    0.6562  0.7894  0.6396  0.6511
# lr                 Logistic Regression    0.6452  0.7875  0.6054  0.6231
# qda    Quadratic Discriminant Analysis    0.6357  0.7881  0.6045  0.6131
# ridge                 Ridge Classifier    0.6338  0.0000  0.5976  0.6153
# svm                SVM - Linear Kernel    0.6313  0.0000  0.5981  0.6254
# dt            Decision Tree Classifier    0.6240  0.6993  0.6059  0.6264
# nb                         Naive Bayes    0.6152  0.7701  0.5833  0.5876
#
#            F1   Kappa     MCC  TT (Sec)
# rf     0.6996  0.5178  0.5203     8.366
# gbc    0.6751  0.4815  0.4862    22.991
# ada    0.6583  0.4537  0.4580     1.932
# knn    0.6523  0.4462  0.4470     2.126
# lr     0.6174  0.4066  0.4201     2.643
# qda    0.6002  0.3988  0.4151     0.081
# ridge  0.5811  0.3893  0.4165     0.066
# svm    0.5603  0.3853  0.4227     0.415
# dt     0.6251  0.3952  0.3953     0.399
# nb     0.5630  0.3682  0.3922     0.066
#                                  Model  Accuracy     AUC  Recall   Prec.  \
# rf            Random Forest Classifier    0.7064  0.8468  0.6799  0.6979
# gbc       Gradient Boosting Classifier    0.6863  0.8332  0.6536  0.6738
# ada               Ada Boost Classifier    0.6695  0.7935  0.6356  0.6562
# knn             K Neighbors Classifier    0.6562  0.7894  0.6396  0.6511
# lr                 Logistic Regression    0.6452  0.7875  0.6054  0.6231
# lda       Linear Discriminant Analysis    0.6394  0.7863  0.6094  0.6200
# qda    Quadratic Discriminant Analysis    0.6357  0.7881  0.6045  0.6131
# ridge                 Ridge Classifier    0.6338  0.0000  0.5976  0.6153
# svm                SVM - Linear Kernel    0.6313  0.0000  0.5981  0.6254
# dt            Decision Tree Classifier    0.6240  0.6993  0.6059  0.6264
# nb                         Naive Bayes    0.6152  0.7701  0.5833  0.5876
#
#            F1   Kappa     MCC  TT (Sec)
# rf     0.6996  0.5178  0.5203     8.366
# gbc    0.6751  0.4815  0.4862    22.991
# ada    0.6583  0.4537  0.4580     1.932
# knn    0.6523  0.4462  0.4470     2.126
# lr     0.6174  0.4066  0.4201     2.643
# lda    0.5995  0.4030  0.4228     0.163
# qda    0.6002  0.3988  0.4151     0.081
# ridge  0.5811  0.3893  0.4165     0.066
# svm    0.5603  0.3853  0.4227     0.415
# dt     0.6251  0.3952  0.3953     0.399
# nb     0.5630  0.3682  0.3922     0.066
#                                  Model  Accuracy     AUC  Recall   Prec.  \
# rf            Random Forest Classifier    0.7064  0.8468  0.6799  0.6979
# et              Extra Trees Classifier    0.6954  0.8318  0.6703  0.6869
# gbc       Gradient Boosting Classifier    0.6863  0.8332  0.6536  0.6738
# ada               Ada Boost Classifier    0.6695  0.7935  0.6356  0.6562
# knn             K Neighbors Classifier    0.6562  0.7894  0.6396  0.6511
# lr                 Logistic Regression    0.6452  0.7875  0.6054  0.6231
# lda       Linear Discriminant Analysis    0.6394  0.7863  0.6094  0.6200
# qda    Quadratic Discriminant Analysis    0.6357  0.7881  0.6045  0.6131
# ridge                 Ridge Classifier    0.6338  0.0000  0.5976  0.6153
# svm                SVM - Linear Kernel    0.6313  0.0000  0.5981  0.6254
# dt            Decision Tree Classifier    0.6240  0.6993  0.6059  0.6264
# nb                         Naive Bayes    0.6152  0.7701  0.5833  0.5876
#
#            F1   Kappa     MCC  TT (Sec)
# rf     0.6996  0.5178  0.5203     8.366
# et     0.6891  0.5015  0.5035     7.424
# gbc    0.6751  0.4815  0.4862    22.991
# ada    0.6583  0.4537  0.4580     1.932
# knn    0.6523  0.4462  0.4470     2.126
# lr     0.6174  0.4066  0.4201     2.643
# lda    0.5995  0.4030  0.4228     0.163
# qda    0.6002  0.3988  0.4151     0.081
# ridge  0.5811  0.3893  0.4165     0.066
# svm    0.5603  0.3853  0.4227     0.415
# dt     0.6251  0.3952  0.3953     0.399
# nb     0.5630  0.3682  0.3922     0.066
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# rf               Random Forest Classifier    0.7064  0.8468  0.6799  0.6979
# lightgbm  Light Gradient Boosting Machine    0.6970  0.8429  0.6678  0.6863
# et                 Extra Trees Classifier    0.6954  0.8318  0.6703  0.6869
# gbc          Gradient Boosting Classifier    0.6863  0.8332  0.6536  0.6738
# ada                  Ada Boost Classifier    0.6695  0.7935  0.6356  0.6562
# knn                K Neighbors Classifier    0.6562  0.7894  0.6396  0.6511
# lr                    Logistic Regression    0.6452  0.7875  0.6054  0.6231
# lda          Linear Discriminant Analysis    0.6394  0.7863  0.6094  0.6200
# qda       Quadratic Discriminant Analysis    0.6357  0.7881  0.6045  0.6131
# ridge                    Ridge Classifier    0.6338  0.0000  0.5976  0.6153
# svm                   SVM - Linear Kernel    0.6313  0.0000  0.5981  0.6254
# dt               Decision Tree Classifier    0.6240  0.6993  0.6059  0.6264
# nb                            Naive Bayes    0.6152  0.7701  0.5833  0.5876
#
#               F1   Kappa     MCC  TT (Sec)
# rf        0.6996  0.5178  0.5203     8.366
# lightgbm  0.6878  0.5009  0.5046     1.812
# et        0.6891  0.5015  0.5035     7.424
# gbc       0.6751  0.4815  0.4862    22.991
# ada       0.6583  0.4537  0.4580     1.932
# knn       0.6523  0.4462  0.4470     2.126
# lr        0.6174  0.4066  0.4201     2.643
# lda       0.5995  0.4030  0.4228     0.163
# qda       0.6002  0.3988  0.4151     0.081
# ridge     0.5811  0.3893  0.4165     0.066
# svm       0.5603  0.3853  0.4227     0.415
# dt        0.6251  0.3952  0.3953     0.399
# nb        0.5630  0.3682  0.3922     0.066
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# rf               Random Forest Classifier    0.7064  0.8468  0.6799  0.6979
# lightgbm  Light Gradient Boosting Machine    0.6970  0.8429  0.6678  0.6863
# et                 Extra Trees Classifier    0.6954  0.8318  0.6703  0.6869
# gbc          Gradient Boosting Classifier    0.6863  0.8332  0.6536  0.6738
# ada                  Ada Boost Classifier    0.6695  0.7935  0.6356  0.6562
# knn                K Neighbors Classifier    0.6562  0.7894  0.6396  0.6511
# lr                    Logistic Regression    0.6452  0.7875  0.6054  0.6231
# lda          Linear Discriminant Analysis    0.6394  0.7863  0.6094  0.6200
# qda       Quadratic Discriminant Analysis    0.6357  0.7881  0.6045  0.6131
# ridge                    Ridge Classifier    0.6338  0.0000  0.5976  0.6153
# svm                   SVM - Linear Kernel    0.6313  0.0000  0.5981  0.6254
# dt               Decision Tree Classifier    0.6240  0.6993  0.6059  0.6264
# nb                            Naive Bayes    0.6152  0.7701  0.5833  0.5876
# dummy                    Dummy Classifier    0.5010  0.5000  0.3333  0.2510
#
#               F1   Kappa     MCC  TT (Sec)
# rf        0.6996  0.5178  0.5203     8.366
# lightgbm  0.6878  0.5009  0.5046     1.812
# et        0.6891  0.5015  0.5035     7.424
# gbc       0.6751  0.4815  0.4862    22.991
# ada       0.6583  0.4537  0.4580     1.932
# knn       0.6523  0.4462  0.4470     2.126
# lr        0.6174  0.4066  0.4201     2.643
# lda       0.5995  0.4030  0.4228     0.163
# qda       0.6002  0.3988  0.4151     0.081
# ridge     0.5811  0.3893  0.4165     0.066
# svm       0.5603  0.3853  0.4227     0.415
# dt        0.6251  0.3952  0.3953     0.399
# nb        0.5630  0.3682  0.3922     0.066
# dummy     0.3344  0.0000  0.0000     0.049
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# rf               Random Forest Classifier    0.7064  0.8468  0.6799  0.6979
# lightgbm  Light Gradient Boosting Machine    0.6970  0.8429  0.6678  0.6863
# et                 Extra Trees Classifier    0.6954  0.8318  0.6703  0.6869
# gbc          Gradient Boosting Classifier    0.6863  0.8332  0.6536  0.6738
# ada                  Ada Boost Classifier    0.6695  0.7935  0.6356  0.6562
# knn                K Neighbors Classifier    0.6562  0.7894  0.6396  0.6511
# lr                    Logistic Regression    0.6452  0.7875  0.6054  0.6231
# lda          Linear Discriminant Analysis    0.6394  0.7863  0.6094  0.6200
# qda       Quadratic Discriminant Analysis    0.6357  0.7881  0.6045  0.6131
# ridge                    Ridge Classifier    0.6338  0.0000  0.5976  0.6153
# svm                   SVM - Linear Kernel    0.6313  0.0000  0.5981  0.6254
# dt               Decision Tree Classifier    0.6240  0.6993  0.6059  0.6264
# nb                            Naive Bayes    0.6152  0.7701  0.5833  0.5876
# dummy                    Dummy Classifier    0.5010  0.5000  0.3333  0.2510
#
#               F1   Kappa     MCC  TT (Sec)
# rf        0.6996  0.5178  0.5203     8.366
# lightgbm  0.6878  0.5009  0.5046     1.812
# et        0.6891  0.5015  0.5035     7.424
# gbc       0.6751  0.4815  0.4862    22.991
# ada       0.6583  0.4537  0.4580     1.932
# knn       0.6523  0.4462  0.4470     2.126
# lr        0.6174  0.4066  0.4201     2.643
# lda       0.5995  0.4030  0.4228     0.163
# qda       0.6002  0.3988  0.4151     0.081
# ridge     0.5811  0.3893  0.4165     0.066
# svm       0.5603  0.3853  0.4227     0.415
# dt        0.6251  0.3952  0.3953     0.399
# nb        0.5630  0.3682  0.3922     0.066
# dummy     0.3344  0.0000  0.0000     0.049
